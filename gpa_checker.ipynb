# %%
# Ivy Pulliam
# gpa_checker.ipynb
# It will ask for a student's name and GPA then test if it'll be in the Dean's List, Honor Roll, or neither.

# %%
while True:
    lastName = input("Enter your last name (or ZZZ to quit): ")
    if lastName == "ZZZ":
        break
    else:
        firstName = input("Enter your first name: ")
        gpa = input("Enter your GPA: ")

        if gpa >= "3.5":
            print(firstName, lastName, "has made the Dean's list.")
        elif gpa >= "3.25":
            print(firstName, lastName, "has made the Honor Roll.")
        else: 
            print(firstName, lastName, "didn't meet requirements for either.")
# Out:
# Enter your last name (or ZZZ to quit):  Pulliam
# Enter your first name:  Ivy
# Enter your GPA:  3.6
# Ivy Pulliam has made the Dean's list.
# Enter your last name (or ZZZ to quit):  Pulliam
# Enter your first name:  Ivy
# Enter your GPA:  3.2
# Ivy Pulliam didn't meet requirements for either.
# Enter your last name (or ZZZ to quit):  Pulliam
# Enter your first name:  Ivy
# Enter your GPA:  3.3
# Ivy Pulliam has made the Honor Roll.
# Enter your last name (or ZZZ to quit):  ZZZ
